# %%
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
TRAIN_PATH = 'C:/Users/js/Desktop/AISPRAK/사회문제 해결형/data/TRAIN/'
TRAIN_AWS_PATH = 'C:/Users/js/Desktop/AISPRAK/사회문제 해결형/data/TRAIN_AWS/'
META_AWS_PATH = 'C:/Users/js/Desktop/AISPRAK/사회문제 해결형/data/META/awsmap.csv'
META_PM_PATH = 'C:/Users/js/Desktop/AISPRAK/사회문제 해결형/data/META/pmmap.csv'

# %%
for file in os.listdir(TRAIN_AWS_PATH):
    df = pd.read_csv(TRAIN_AWS_PATH+file)
    print(df.shape)
    print()
    print("Null 개수" + ' ' + file + " : ")
    print(df.isnull().sum())
    print()
# Out:
# (35064, 8)
#
# Null 개수 계룡.csv :
# 연도            0
# 일시            0
# 지점            0
# 기온(°C)     1064
# 풍향(deg)    1064
# 풍속(m/s)    1064
# 강수량(mm)    1064
# 습도(%)      1064
# dtype: int64
#
# (35064, 8)
#
# Null 개수 공주.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     684
# 풍향(deg)    684
# 풍속(m/s)    684
# 강수량(mm)    684
# 습도(%)      684
# dtype: int64
#
# (35064, 8)
#
# Null 개수 논산.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     488
# 풍향(deg)    488
# 풍속(m/s)    488
# 강수량(mm)    488
# 습도(%)      488
# dtype: int64
#
# (35064, 8)
#
# Null 개수 당진.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     406
# 풍향(deg)    406
# 풍속(m/s)    406
# 강수량(mm)    406
# 습도(%)      406
# dtype: int64
#
# (35064, 8)
#
# Null 개수 대산.csv :
# 연도            0
# 일시            0
# 지점            0
# 기온(°C)     1029
# 풍향(deg)    1029
# 풍속(m/s)    1029
# 강수량(mm)    1029
# 습도(%)      1029
# dtype: int64
#
# (35064, 8)
#
# Null 개수 대천항.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     455
# 풍향(deg)    455
# 풍속(m/s)    455
# 강수량(mm)    455
# 습도(%)      455
# dtype: int64
#
# (35064, 8)
#
# Null 개수 북격렬비도.csv :
# 연도            0
# 일시            0
# 지점            0
# 기온(°C)     1914
# 풍향(deg)    1914
# 풍속(m/s)    1914
# 강수량(mm)    1914
# 습도(%)      1914
# dtype: int64
#
# (35064, 8)
#
# Null 개수 서천.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     188
# 풍향(deg)    188
# 풍속(m/s)    188
# 강수량(mm)    188
# 습도(%)      188
# dtype: int64
#
# (35064, 8)
#
# Null 개수 성거.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     481
# 풍향(deg)    481
# 풍속(m/s)    481
# 강수량(mm)    481
# 습도(%)      481
# dtype: int64
#
# (35064, 8)
#
# Null 개수 세종고운.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     300
# 풍향(deg)    300
# 풍속(m/s)    300
# 강수량(mm)    300
# 습도(%)      300
# dtype: int64
#
# (35064, 8)
#
# Null 개수 세종금남.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     107
# 풍향(deg)    107
# 풍속(m/s)    107
# 강수량(mm)    107
# 습도(%)      107
# dtype: int64
#
# (35064, 8)
#
# Null 개수 세종연서.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     478
# 풍향(deg)    478
# 풍속(m/s)    478
# 강수량(mm)    478
# 습도(%)      478
# dtype: int64
#
# (35064, 8)
#
# Null 개수 세종전의.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     324
# 풍향(deg)    324
# 풍속(m/s)    324
# 강수량(mm)    324
# 습도(%)      324
# dtype: int64
#
# (35064, 8)
#
# Null 개수 세천.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     388
# 풍향(deg)    388
# 풍속(m/s)    388
# 강수량(mm)    388
# 습도(%)      388
# dtype: int64
#
# (35064, 8)
#
# Null 개수 아산.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     493
# 풍향(deg)    493
# 풍속(m/s)    493
# 강수량(mm)    493
# 습도(%)      493
# dtype: int64
#
# (35064, 8)
#
# Null 개수 안도.csv :
# 연도            0
# 일시            0
# 지점            0
# 기온(°C)     1268
# 풍향(deg)    1268
# 풍속(m/s)    1268
# 강수량(mm)    1268
# 습도(%)      1268
# dtype: int64
#
# (35064, 8)
#
# Null 개수 양화.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     529
# 풍향(deg)    529
# 풍속(m/s)    529
# 강수량(mm)    529
# 습도(%)      529
# dtype: int64
#
# (35064, 8)
#
# Null 개수 예산.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     404
# 풍향(deg)    404
# 풍속(m/s)    404
# 강수량(mm)    404
# 습도(%)      404
# dtype: int64
#
# (35064, 8)
#
# Null 개수 오월드.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     471
# 풍향(deg)    471
# 풍속(m/s)    471
# 강수량(mm)    471
# 습도(%)      471
# dtype: int64
#
# (35064, 8)
#
# Null 개수 옹도.csv :
# 연도            0
# 일시            0
# 지점            0
# 기온(°C)     1452
# 풍향(deg)    1452
# 풍속(m/s)    1452
# 강수량(mm)    1452
# 습도(%)      1452
# dtype: int64
#
# (35064, 8)
#
# Null 개수 유구.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     462
# 풍향(deg)    462
# 풍속(m/s)    462
# 강수량(mm)    462
# 습도(%)      462
# dtype: int64
#
# (35064, 8)
#
# Null 개수 장동.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     840
# 풍향(deg)    840
# 풍속(m/s)    840
# 강수량(mm)    840
# 습도(%)      840
# dtype: int64
#
# (35064, 8)
#
# Null 개수 정산.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     501
# 풍향(deg)    501
# 풍속(m/s)    501
# 강수량(mm)    501
# 습도(%)      501
# dtype: int64
#
# (35064, 8)
#
# Null 개수 정안.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     413
# 풍향(deg)    413
# 풍속(m/s)    413
# 강수량(mm)    413
# 습도(%)      413
# dtype: int64
#
# (35064, 8)
#
# Null 개수 청양.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     454
# 풍향(deg)    454
# 풍속(m/s)    454
# 강수량(mm)    454
# 습도(%)      454
# dtype: int64
#
# (35064, 8)
#
# Null 개수 춘장대.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     345
# 풍향(deg)    345
# 풍속(m/s)    345
# 강수량(mm)    345
# 습도(%)      345
# dtype: int64
#
# (35064, 8)
#
# Null 개수 태안.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     659
# 풍향(deg)    659
# 풍속(m/s)    659
# 강수량(mm)    659
# 습도(%)      659
# dtype: int64
#
# (35064, 8)
#
# Null 개수 호도.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     714
# 풍향(deg)    714
# 풍속(m/s)    714
# 강수량(mm)    714
# 습도(%)      714
# dtype: int64
#
# (35064, 8)
#
# Null 개수 홍북.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     841
# 풍향(deg)    841
# 풍속(m/s)    841
# 강수량(mm)    841
# 습도(%)      841
# dtype: int64
#
# (35064, 8)
#
# Null 개수 홍성죽도.csv :
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     796
# 풍향(deg)    796
# 풍속(m/s)    796
# 강수량(mm)    796
# 습도(%)      796
# dtype: int64
