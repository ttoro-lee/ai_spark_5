# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# 한글 사용 plt 설치 > https://github.com/ychoi-kr/koreanize-matplotlib 참조
# !pip install koreanize-matplotlib

# %%
# 필요한 라이브러리 설치 및 임포트
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import koreanize_matplotlib # 한글 사용을 위한 import
import os

import warnings
warnings.filterwarnings(action='ignore')

# %%
train_path = '/content/drive/MyDrive/공모전/dataset/TRAIN/'
forders= os.listdir(train_path)

data = pd.read_csv(train_path + forders[0])
print(forders[0])
display(data.head(2))
display(data.info())
# Out:
# 신흥동.csv
#    연도           일시  측정소  PM2.5
# 0   0  01-01 00:00  신흥동  0.044
# 1   0  01-01 01:00  신흥동  0.064
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      35064 non-null  int64
#  1   일시      35064 non-null  object
#  2   측정소     35064 non-null  object
#  3   PM2.5   34305 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB
# None

# %%
train_path = '/content/drive/MyDrive/공모전/dataset/TRAIN/'
aws_path = '/content/drive/MyDrive/공모전/dataset/TRAIN_AWS/'
awsmap = pd.read_csv("/content/drive/MyDrive/공모전/dataset/META/awsmap.csv")
pmmap = pd.read_csv("/content/drive/MyDrive/공모전/dataset/META/pmmap.csv")
forders= os.listdir(train_path)
for forder in forders :
    data = pd.read_csv(train_path + forder)
    data.plot(kind='line', x='일시', y='PM2.5', title=data['측정소'][0],  figsize=(18, 6))
    print()

# %%
forders= os.listdir(train_path)
for forder in forders :
    data = pd.read_csv(train_path + forder)
    print(forder)
    display(data.isna().sum())
    display(data.head(2))
    display(data.describe())
    display(data.info())
    print()
# Out:
# 신흥동.csv
# 연도         0
# 일시         0
# 측정소        0
# PM2.5    759
# dtype: int64
#    연도           일시  측정소  PM2.5
# 0   0  01-01 00:00  신흥동  0.044
# 1   0  01-01 01:00  신흥동  0.064
#                  연도         PM2.5
# count  35064.000000  34305.000000
# mean       1.501027      0.090019
# std        1.118356      0.077535
# min        0.000000      0.000000
# 25%        1.000000      0.036000
# 50%        2.000000      0.072000
# 75%        3.000000      0.124000
# max        3.000000      0.804000
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35064 entries, 0 to 35063
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   연도      35064 non-null  int64
#  1   일시      35064 non-null  object
#  2   측정소     35064 non-null  object
#  3   PM2.5   34305 non-null  float64
# dtypes: float64(1), int64(1), object(2)
# memory usage: 1.1+ MB
# None
# 신방동.csv
# 연도         0
# 일시         0
# 측정소        0
# ...

# %%
forders= os.listdir(aws_path)

data = pd.read_csv(aws_path + forders[0])
print(forder)
data.plot(kind='line', x='일시', y='기온(°C)', figsize=(18, 6))
print()
# Out:
# 이원면.csv

# %%
forders= os.listdir(aws_path)

data = pd.read_csv(aws_path + forders[0])
print(forder)
data.plot(kind='line', x='일시', y='풍향(deg)', figsize=(18, 6))
print()
# Out:
# 이원면.csv

# %%
forders= os.listdir(aws_path)

data = pd.read_csv(aws_path + forders[0])
print(forder)
data.plot(kind='line', x='일시', y='풍속(m/s)', figsize=(18, 6))
print()
# Out:
# 이원면.csv

# %%
forders= os.listdir(aws_path)

data = pd.read_csv(aws_path + forders[0])
print(forder)
data.plot(kind='line', x='일시', y='강수량(mm)', figsize=(18, 6))
print()
# Out:
# 이원면.csv

# %%
forders= os.listdir(aws_path)

data = pd.read_csv(aws_path + forders[0])
print(forder)
data.plot(kind='line', x='일시', y='습도(%)', figsize=(18, 6))
print()
# Out:
# 이원면.csv

# %%
forders= os.listdir(aws_path)
for forder in forders :
    data = pd.read_csv(aws_path + forder)
    print(forder)
    display(data.isna().sum())
    display(data.head(2))
    display(data.describe())
    display(data.info())
    print()
# Out:
# 당진.csv
# 연도           0
# 일시           0
# 지점           0
# 기온(°C)     406
# 풍향(deg)    406
# 풍속(m/s)    406
# 강수량(mm)    406
# 습도(%)      406
# dtype: int64
#    연도           일시  지점   기온(°C)   풍향(deg)   풍속(m/s)  강수량(mm)  습도(%)
# 0   0  01-01 00:00  당진  0.21485  0.892222  0.066496      0.0  0.707
# 1   0  01-01 01:00  당진  0.21169  0.902778  0.043478      0.0  0.797
#                  연도        기온(°C)       풍향(deg)       풍속(m/s)       강수량(mm)  \
# count  35064.000000  34658.000000  34658.000000  34658.000000  34658.000000
# mean       1.501027      0.573369      0.462748      0.038398      0.001422
# std        1.118356      0.162357      0.330602      0.030374      0.010242
# min        0.000000      0.094787      0.000000      0.000000      0.000000
# 25%        1.000000      0.442338      0.150556      0.015345      0.000000
# 50%        2.000000      0.579779      0.525417      0.033248      0.000000
# ...

# %%
# 아래는 미진행

# %%
# def eda1_n(data,var,bbin = 20) : # = 20은 디폴트값 지정
#     # 기초통계량
#     display(data[[var]].describe().T)

#     # 시각화
#     plt.figure(figsize = (4,5))
#     plt.subplot(2,1,1)
#     sns.histplot(x = var, data = data, bins = bbin, kde = True)

#     plt.subplot(2,1,2)
#     sns.boxplot(x = var, data = data)
#     plt.grid()
#     plt.show()

# %%
# data.corr()

# %%
# plt.figure(figsize = (8, 8))
# sns.pairplot(data)
# plt.show()

# %%
# plt.figure(figsize = (8, 8))
# sns.heatmap(data.corr(), 
#             annot = True,            # 숫자(상관계수) 표기 여부
#             fmt = '.3f',             # 숫자 포멧 : 소수점 3자리까지 표기
#             cmap = 'Blues',       # 칼라맵
#             vmin = -1, vmax = 1)     # 값의 최소, 최대값값
# plt.show()
